# %% [markdown]
# # Dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from glob import glob

import pandas as pd

try:
    os.chdir('/home/users/alexno/narcolepsy-detector')
except:
    pass

# %% [markdown]
# # Prepare data

# %%
df = pd.read_csv('./data_master.csv')
df = df.loc[df['Narcolepsy training data'] == 1, :]
print('ALL DATA')
display(df.head())
print(len(df))
display(df.groupby('Cohort').size())

print('')
print("DATA WITH FEATURES")
df_feat = pd.read_csv('./data/narco_features/avg_kw21_r01_trainD_unscaled.csv')
display(df_feat.head())
print(len(df_feat))
display(df_feat.groupby('Cohort').size())
# Out:
# ALL DATA
#    Unnamed: 0   Index                ID            FileID ID-ling Cohort  \
# 0           0     NaN  SSC_NARCO_1508_1  SSC_NARCO_1508_1    1508    SSC
# 1           1     NaN  SSC_NARCO_1534_1  SSC_NARCO_1534_1    1534    SSC
# 3           3     NaN  SSC_NARCO_1647_1  SSC_NARCO_1647_1    1647    SSC
# 4           4  1267.0        SSC_1958_1        SSC_1958_1    1958    SSC
# 5           5     NaN  SSC_NARCO_1994_1  SSC_NARCO_1994_1    1994    SSC
#
#          Diagnosis  Label  Sleep scoring training data  \
# 0  'T1 NARCOLEPSY'      1                            0
# 1  'T1 NARCOLEPSY'      1                            0
# 3  'T1 NARCOLEPSY'      1                            0
# 4  'T1 NARCOLEPSY'      1                            0
# 5  'T1 NARCOLEPSY'      1                            0
#
#    Sleep scoring test data  Narcolepsy training data  Narcolepsy test data  \
# 0                        1                         1                     0
# ...

# %% [markdown]
# # Missing data

# %% [markdown]
# ## DHC

# %%
display(df.query('Cohort == "DHC"').merge(df_feat.query('Cohort == "DHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'])
display(df.query('Cohort == "DHC"').merge(df_feat.query('Cohort == "DHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'].groupby('Diagnosis').size())
# Out:
#     Unnamed: 0_x  Index     ID FileID ID-ling Cohort_x            Diagnosis  \
# 15          1308  711.0  Sub01  Sub01     NaN      DHC  'OTHER HYPERSOMNIA'
# 16          1310  723.0  Sub14  Sub14     NaN      DHC  'OTHER HYPERSOMNIA'
#
#     Label_x  Sleep scoring training data  Sleep scoring test data  ...  480  \
# 15        0                            0                        0  ...  NaN
# 16        0                            0                        0  ...  NaN
#
#     481  482  483 484 485  486  487 488     _merge
# 15  NaN  NaN  NaN NaN NaN  NaN  NaN NaN  left_only
# 16  NaN  NaN  NaN NaN NaN  NaN  NaN NaN  left_only
#
# [2 rows x 510 columns]
# Diagnosis
# 'OTHER HYPERSOMNIA'    2
# dtype: int64

# %% [markdown]
# ## IHC

# %%
df.query('Cohort == "IHC"')
# Out:
#      Unnamed: 0  Index     ID        FileID ID-ling Cohort  \
# 278         278    NaN  15125         15125   15125    IHC
# 279         279    NaN  16351         16351   16351    IHC
# 281         281    NaN  16839         16839   16839    IHC
# 282         282    NaN  17378  17378vmnotte   17378    IHC
# 284         284    NaN  17599         17599   17599    IHC
# ..          ...    ...    ...           ...     ...    ...
# 470         470  833.0  26274  26274lpnotte   26274    IHC
# 471         471  834.0  26603  26603fsnotte   26603    IHC
# 473         473  836.0  26739  26739donotte   26739    IHC
# 474         474  837.0  26859  26859rpnotte   26859    IHC
# 475         475    NaN  29126         29126   29126    IHC
#
#                Diagnosis  Label  Sleep scoring training data  \
# 278      'T1 NARCOLEPSY'      1                            0
# 279  'OTHER HYPERSOMNIA'      0                            0
# 281  'OTHER HYPERSOMNIA'      0                            0
# ...

# %%
display(df.query('Cohort == "IHC"').merge(df_feat.query('Cohort == "IHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'])
display(df.query('Cohort == "IHC"').merge(df_feat.query('Cohort == "IHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'].groupby('Diagnosis').size())
# Out:
#      Unnamed: 0_x  Index     ID        FileID ID-ling Cohort_x  \
# 0             278    NaN  15125         15125   15125      IHC
# 1             279    NaN  16351         16351   16351      IHC
# 2             281    NaN  16839         16839   16839      IHC
# 3             282    NaN  17378  17378vmnotte   17378      IHC
# 4             284    NaN  17599         17599   17599      IHC
# ..            ...    ...    ...           ...     ...      ...
# 112           470  833.0  26274  26274lpnotte   26274      IHC
# 113           471  834.0  26603  26603fsnotte   26603      IHC
# 114           473  836.0  26739  26739donotte   26739      IHC
# 115           474  837.0  26859  26859rpnotte   26859      IHC
# 116           475    NaN  29126         29126   29126      IHC
#
#                Diagnosis  Label_x  Sleep scoring training data  \
# 0        'T1 NARCOLEPSY'        1                            0
# 1    'OTHER HYPERSOMNIA'        0                            0
# ...

# %% [markdown]
# ## KHC

# %%
display(df.query('Cohort == "KHC"').merge(df_feat.query('Cohort == "KHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'])
display(df.query('Cohort == "KHC"').merge(df_feat.query('Cohort == "KHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'].groupby('Diagnosis').size())
# Out:
#     Index        ID ID-ling Cohort_x                 Diagnosis  Label_x  \
# 36  847.0   7604506    P422      KHC       'OTHER HYPERSOMNIA'        0
# 38  854.0   9205252    P439      KHC       'OTHER HYPERSOMNIA'        0
# 46  840.0   3819172    P475      KHC       'OTHER HYPERSOMNIA'        0
# 51   97.0   9182911    P489      KHC  'NON-NARCOLEPSY CONTROL'        0
# 67  853.0   8573814    P533      KHC       'OTHER HYPERSOMNIA'        0
# 68  845.0   6985471    P534      KHC       'OTHER HYPERSOMNIA'        0
# 73   94.0   5802756    P544      KHC  'NON-NARCOLEPSY CONTROL'        0
# 82  838.0   1893252    P567      KHC       'OTHER HYPERSOMNIA'        0
# 83   95.0   6406051    P569      KHC  'NON-NARCOLEPSY CONTROL'        0
# 88    NaN  16186811     NaN      KHC  'NON-NARCOLEPSY CONTROL'        0
# 89    NaN  16384988     NaN      KHC  'NON-NARCOLEPSY CONTROL'        0
#
#     Sleep scoring training data  Sleep scoring test data  \
# ...

# %% [markdown]
# ## WSC

# %%
display(df.query('Cohort == "WSC"').merge(df_feat.query('Cohort == "WSC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'])
display(df.query('Cohort == "WSC"').merge(df_feat.query('Cohort == "WSC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'].groupby('Diagnosis').size())
# Out:
#     Index              ID ID-ling Cohort_x                 Diagnosis  Label_x  \
# 47    NaN  A2003_6 172441   A2003      WSC  'NON-NARCOLEPSY CONTROL'        0
#
#     Sleep scoring training data  Sleep scoring test data  \
# 47                            0                        1
#
#     Narcolepsy training data  Narcolepsy test data  ...  480  481 482 483  \
# 47                         1                     0  ...  NaN  NaN NaN NaN
#
#     484  485 486  487  488     _merge
# 47  NaN  NaN NaN  NaN  NaN  left_only
#
# [1 rows x 508 columns]
# Diagnosis
# 'NON-NARCOLEPSY CONTROL'    1
# dtype: int64

# %% [markdown]
# ## AHC

# %%
display(df.query('Cohort == "AHC" or Cohort == "2AHC"').merge(df_feat.query('Cohort == "AHC" or Cohort == "2AHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'])
display(df.query('Cohort == "AHC" or Cohort == "2AHC"').merge(df_feat.query('Cohort == "AHC" or Cohort == "2AHC"'), indicator=True, how='left', left_on='ID', right_on='ID').loc[lambda x: x['_merge'] != 'both'].groupby('Diagnosis').size())
# Out:
#       Index         ID ID-ling Cohort_x            Diagnosis  Label_x  \
# 0     670.0  INN002 N1  INN002      AHC  'OTHER HYPERSOMNIA'        0
# 1     634.0  INN002 N2  INN002     2AHC  'OTHER HYPERSOMNIA'        0
# 2     960.0  INN003 N1  INN003      AHC      'T1 NARCOLEPSY'        1
# 3     922.0  INN003 N2  INN003     2AHC      'T1 NARCOLEPSY'        1
# 4     671.0  INN004 N1  INN004      AHC  'OTHER HYPERSOMNIA'        0
# ..      ...        ...     ...      ...                  ...      ...
# 96    668.0  INN094 N2  INN094     2AHC  'OTHER HYPERSOMNIA'        0
# 97   1002.0  INN096 N1  INN096      AHC      'T1 NARCOLEPSY'        1
# 98    957.0  INN096 N2  INN096     2AHC      'T1 NARCOLEPSY'        1
# 99    710.0  INN097 N1  INN097      AHC  'OTHER HYPERSOMNIA'        0
# 100   669.0  INN097 N2  INN097     2AHC  'OTHER HYPERSOMNIA'        0
#
#      Sleep scoring training data  Sleep scoring test data  \
# 0                              0                        0
# ...
